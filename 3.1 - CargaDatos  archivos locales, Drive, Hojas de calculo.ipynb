# %% [markdown]
# # Lectura de archivos
#
#
# Semana Tec
#
# Profesores: Luz Eunice Angeles /José Ignacio Treviño

# %% [markdown]
# Qué aprenderemos:
#
# - Subir archivos desde el sistema de archivos local
# - Descargar archivos en el slistema de archivos local
# - Acceder a google drive
#   - Activarlo de en el entorno de ejecución
#   - Usar una API : PyDrive
# - Crear y leer datos de google sheets

# %% [markdown]
# ## Subir archivos desde el sistema de archivos local
#
# <code>files.upload</code> es usado para cargar los archivos y conocer el diccionario de los archivos que se cargaron.
# El diccionario está codificado según el nombre de archivo y los valores son los datos que se subieron.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-5aad7cd0-05b7-408f-8634-0cac5c39acc8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5aad7cd0-05b7-408f-8634-0cac5c39acc8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving netflix_titles.csv to netflix_titles.csv
# User uploaded file "netflix_titles.csv" with length 3000491 bytes

# %% [markdown]
# ## Descargar archivos en el sistema de archivos local
#
# <code>files.download</code> invocará una descarga del archivo desde el navegador a tu computadora local.

# %%
from google.colab import files

with open('example.txt', 'w') as f:
  f.write('some content')

files.download('example.txt')

# %%
ls
# Out:
# example.txt  sample_data/

# %% [markdown]
# # Google Drive
#
# Puedes acceder a archivos en Drive de varias maneras, incluidas las siguientes:
# - Activación de Google Drive en la máquina virtual del entorno de ejecución
# - Usar un wrapper alrededor de la API, como <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">PyDrive</a>
# - Usar la <a href="https://developers.google.com/drive/v3/web/about-sdk">API nativa de REST</a>
#
#
#
# Puedes ver ejemplos de cada caso más abajo.

# %% [markdown]
# ## Activar Google Drive de forma local
#
# El ejemplo siguiente muestra cómo activar Google Drive en el entorno de ejecución mediante un código de autorización y cómo escribir y leer archivos allí. Una vez ejecutado, podrás ver el archivo nuevo &#40;<code>foo.txt</code>&#41; en <a href="https://drive.google.com/">https://drive.google.com/</a>.
#
# Ten en cuenta que solo se puede leer, escribir o mover archivos.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/SemanaTec/example.txt', 'w') as f:
  f.write('Hello Google Drive example!')
# !cat /content/drive/My\ Drive/SemanaTec/example.txt
# Out:
# Hello Google Drive example!

# %% [markdown]
# ## PyDrive
#
# En los ejemplos que aparecen a continuación, se muestran la autenticación y la carga y descarga de archivos mediante PyDrive. Puedes encontrar más ejemplos en la <a href="https://gsuitedevs.github.io/PyDrive/docs/build/html/index.html">documentación de PyDrive</a>.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Autentica y crea el cliente de PyDrive.

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Lista de ids de cada carpeta que tenemos en el google drive

# %%
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:       
    print ('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: 2.1 - Basicos de Unix - Github.ipynb, id: 1mOob3zZ_U4C4WYw4scvw4HFXVCsrs5Iw
# title: SemanaTec, id: 1kP8bhtiFDpuMwX97TUZCPza7LoBA98MJ
# title: Actividad Integradora 3.4 Resaltador de sintaxis , id: 17I7g__I5kFNztAfCGZB7sXUs_5ZpD24XTCL_USld7Y0
# title: Activity06_A01280544.docx, id: 1EQgdIH9rrhfVX-AiQAC3iKF4DAxQ8Zhe
# title: Modelo ERD Aplicación, id: 1JU4tTedOrV6yCGXg-GWHBvjfBdIb7SWDa7rE6Xe1ULg
# title: Calificacioness, id: 19zU7esCfUkJyl9dHYFxoOSBEID8Lm6GnHom_zR1jHyI
# title: Alumnoss, id: 1JczFZ4O5neu9zTH1-vczPfHoXKfRbbWRfv-jDZ8nMIU
# title: Documento sin título, id: 12W7lWMzIFnPKzZc2RCK1zKdLLmwd39OB7jI71jO7fuE
# title: Mein Tag.pptx, id: 1P_wBWODndFnYN4aATdzvkP_OHOdLtjUWcVsxUDdypUQ
# title: Tablas Conceptuales.docx, id: 1A3SMaysPxmEjyn-4v8vqfMohCwzLa1zJIsvOHAlL4mI
# title: Tablas Conceptuales.docx, id: 1hNXwmu8xqYXxvAxt90h3PROGvPeP3j5Q
# title: actividad-sistema-respiratorio-repaso (1).docx, id: 16_j_MGxeNvvM6kMzuCBvv_X8nakCQrWlvh63AlN5ANo
# title: Jackeline Conant Rubalcava A01280544   Habla de ti.mp4, id: 1czpwSZcZfKFASguAA_9AM3kzmiVFNnLY
# title: Preguntas Neoclásico.docx, id: 1rTh75ruOE65MSd-zDmmEVf3hN9RiKaGtcKIE-RWZGhM
# title: Preguntas Neoclásico.docx, id: 1WNdEQghViEZD21nAPRuscIDSgivBxy2v
# title: guion_doblaje_audio.docx, id: 1TNLDXR3GgQSZMg2npzbfuowkDZ967yM3rKFTT80rL6M
# title: Guión de doblaje de audio.docx, id: 1pq8ktZofHn2Byz7YzTO_7aN-q6_6Cmoirft-tZloqCQ
# title: Doblaje de audio_vines.mp4, id: 1cd0EDH8kaBcGNL7OB_pkTXR1ltGZmL01
# title: Guión de doblaje de audio.docx, id: 1k4v_-V9UHEiKkkf8gYIk6v_ZQcJrowZxcOryinLI8rw
# title: guion_doblaje_audio.docx, id: 1AvV7WgUBz4rcfdYJSTDnJnbj8L-VepNEmliJHJAmDbM
# title: guion_doblaje_audio.docx, id: 1hT9JajX8ck1umbCI_dxel-k_uy9y-4NN
# title: Guión de doblaje de audio.docx, id: 1yHnPsnIKCK1mA5IbhfD4U0aFFoWcY--p
# title: 01 LEAyL - Actividad de analisis Edipo Rey 2018.docx, id: 1jhkcAbzr7lDaJRd7mVxcs4nixBx8yDKWO0PUD0t1F2M
# title: 01 LEAyL - Actividad de analisis Edipo Rey 2018.docx, id: 1jGkjxNdHKY0NAuqYaYrSB4VQWhKd19Lr
# title: Jackeline Conant Rubalcava, id: 1TS6d7sGL_uVBj3-GI0LU7ozVfwr6tXiR
# title: Historia de la Literatura, id: 1KFnpAe_QZXGhc8vcjimxwBd1hHJYtnhr4kCEISLZCvQ
# title: The American and French Revolution are some of the most important events of this two countries history.docx, id: 1ThcOFLF8fw4IEfQarxVCxLjz5eRA7jm5YtFPU5x4cZA
# title: Portafolio, id: 1w3grMy9VP9EU6s8GZimiM6_Chax52jeX
# title: Detonating activity Third Partial (2).docx, id: 1IPxTsl8rBingf8g250eZuIPiS_nV99Fw
# title: Detonating activity Third Partial (1).docx, id: 1cFYuesrw5Wi2axqacLhrj9CAkabwfpgH
# title: Detonating activity Third Partial (1).docx, id: 17RC0xcVFLW61NfQAQb8zM80_Xnb0NTn7D-ZRhWE4-38
# title: Detonating activity Third Partial (1).docx - Bar chart 1, id: 1WudMhWgJ-nUUrZFh2H-HGG4I0jML-e2jFF84T6JxPzA
# title: Detonating activity Third Partial (1).docx - Bar chart 1, id: 1BkwzMaUDr09n2VaDYu0E4ArGv2M0lTdP7QSNIzslDj8
# title: Detonating activity Third Partial (1).docx - Bar chart 1, id: 1Nw7u1gJduvyzAWgxA4QLG0Mh6CxbASWQJDWo-_luEpA
# title: PLAN DE VIDA ESTUDIANTIL (1) (1).docx, id: 1bQmLvVc_je-_VEUremzfIAB3OJ_ajL2P
# title: Detonating activity Third Partial (1).docx, id: 1ccyLTrzDKi04Pj1NCjvuBxZX0IPQm85XPf0_kP3I7cc
# title: PERSONAL DEVELOPMENT PLAN TEMPLATE (1).docx, id: 1dophi8h6lFveJWaYam_dXzTHc6ZLUKTt
# title: GOALS TEMPLATE.docx, id: 1lLVdaLxesjsPq4PYgG3DJxbTFSGAJh_z
# title: My experience in Prepa Tec.docx, id: 1DvsWsAkytCx-O-_0Ub7YP3yK3yur-cFD
# title: The American and French Revolution are some of the most important events of this two countries history.docx, id: 1U7_W9OAF3N0NAqPVEHWRi8f0VEgFGr5MG6bqZmUweuQ
# title: Doc1.docx, id: 0B9PVwZh2Ngp4WmozOThvVGk4VGs
# title: The American and French Revolution are some of the most important events of this two countries history.docx, id: 1SW1sAM1ie2R4686PsmxTW4ryJxDkYC45v_HBbyRQhaA
# title: The American and French Revolution are some of the most important events of this two countries history.docx, id: 1QgLhHY82mZ8Q5ahrb93dztqUqcvdndPMuzNi_P_mJPQ
# title: 406_JackelineConant_act 6.jpg, id: 0B9PVwZh2Ngp4T0JIdW1qOEpQbkU
# title: Mein Tag.pptx, id: 0B9PVwZh2Ngp4MzA2T2loUF83dDg
# title: CARTA_COMPROMISO.jpg, id: 0B9PVwZh2Ngp4TVVXU3R6M09Ib1k
# title: Rúbrica 1er trabajo parcial.docx, id: 0B9PVwZh2Ngp4dEhNZEN1bHJtSjg
# title: Proyecto 1er parcial.docx, id: 10w9mHfzUCXEpV8NLb9o0mseYn7UJmcBBbBUWTqPfRkw
# title: Proyecto 1er parcial.docx, id: 1-geLFExpjjMArF2uQ4pnLOXPXsaVYI9EHtKsdGEf8tQ
# title: Microscope Activity.doc, id: 0B9PVwZh2Ngp4c0FSMkR3Q3Y4dDQ
# title: Mijail Kolvenik.docx, id: 0B9PVwZh2Ngp4YUhoaVpLY0trZkU

# %%
fid= '1r3STNnFiq8uRhifgq96dbO2keF58zFqU'

# %% [markdown]
# Crea y sube un archivo de texto.

# %%
uploaded = drive.CreateFile({'title': 'example.txt','parents':[{"id":fid}]})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# ---------------------------------------------------------------------------
# ResumableUploadError                      Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in _FilesInsert(self, param)
#     368       metadata = self.auth.service.files().insert(**param).execute(
# --> 369         http=self.http)
#     370     except errors.HttpError as error:
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     878             while body is None:
# --> 879                 _, body = self.next_chunk(http=http, num_retries=num_retries)
#     880             return body
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# /usr/local/lib/python3.7/dist-packages/googleapiclient/http.py in next_chunk(self, http, num_retries)
#     998             else:
# --> 999                 raise ResumableUploadError(resp, content)
#    1000         elif self._in_error_state:
#
# ResumableUploadError: <HttpError 404 when requesting None returned "File not found: 1r3STNnFiq8uRhifgq96dbO2keF58zFqU". Details: "File not found: 1r3STNnFiq8uRhifgq96dbO2keF58zFqU">
#
# During handling of the above exception, another exception occurred:
#
# ApiRequestError                           Traceback (most recent call last)
# <ipython-input-25-abeb14100909> in <module>()
#       1 uploaded = drive.CreateFile({'title': 'example.txt','parents':[{"id":fid}]})
#       2 uploaded.SetContentString('Sample upload file content')
# ----> 3 uploaded.Upload()
#       4 print('Uploaded file with ID {}'.format(uploaded.get('id')))
#
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in Upload(self, param)
#     283         self._FilesPatch(param=param)
#     284     else:
# --> 285       self._FilesInsert(param=param)
#     286
#     287   def Trash(self, param=None):
#
# /usr/local/lib/python3.7/dist-packages/pydrive/auth.py in _decorated(self, *args, **kwargs)
#      73       self.http = self.auth.Get_Http_Object()
#      74
# ---> 75     return decoratee(self, *args, **kwargs)
#      76   return _decorated
#      77
#
# /usr/local/lib/python3.7/dist-packages/pydrive/files.py in _FilesInsert(self, param)
#     369         http=self.http)
#     370     except errors.HttpError as error:
# --> 371       raise ApiRequestError(error)
#     372     else:
#     373       self.uploaded = True
#
# ApiRequestError: <HttpError 404 when requesting None returned "File not found: 1r3STNnFiq8uRhifgq96dbO2keF58zFqU". Details: "File not found: 1r3STNnFiq8uRhifgq96dbO2keF58zFqU">

# %% [markdown]
# Carga un archivo por su ID y luego imprime su contenido.

# %%
uploaded.get('id')
# Out:
# '1irKkQkYNkGqKVMitMGtJtK3nJYbZ8OAX'

# %%
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Sample upload file content
# modificar"

# %% [markdown]
# # Hojas de cálculo de Google
#
# Los ejemplos de abajo usan la biblioteca de código abierto <a href="https://github.com/burnash/gspread"><code>gspread</code></a> para interactuar con Hojas de cálculo de Google.
#
# Primero, instala el paquete usando <code>pip</code>.

# %%
# !pip install --upgrade --quiet gspread

# %% [markdown]
# Importa la biblioteca, autentica y crea la interfaz para Hojas de cálculo.

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %% [markdown]
# A continuación, verás un pequeño conjunto de ejemplos de <code>gspread</code>. Puedes encontrar más ejemplos en la <a href="https://github.com/burnash/gspread#more-examples">página de GitHub de <code>gspread</code></a>.

# %% [markdown]
# ## Crear una hoja nueva con datos de Python

# %%
sh = gc.create('My cool spreadsheet')

# %% [markdown]
# Después de ejecutar la celda anterior, se mostrará una nueva hoja de cálculo con el nombre "My cool spreadsheet" en <a href="https://sheets.google.com/">https://sheets.google.com</a>.
#
# Abre la hoja nueva y agrega datos aleatorios.

# %%
worksheet = gc.open('My cool spreadsheet').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1tE6ynMLATZl1HJtFGp9KmjmjC292JTNEgyu8BK4ZBtU',
#  'updatedCells': 6,
#  'updatedColumns': 3,
#  'updatedRange': 'Sheet1!A1:C2',
#  'updatedRows': 2}

# %% [markdown]
# ## Descargar datos de una hoja de cálculo en Python como un DataFrame de Pandas
#
# Vuelve a leer los datos aleatorios que insertamos anteriormente y convierte el resultado en un <a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html">DataFrame de Pandas</a>.

# %%
worksheet = gc.open('My cool spreadsheet').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print('******************Lista de datos*********************')
print(rows)

import pandas as pd
dataset=pd.DataFrame.from_records(rows)
print('******************Data Frame*********************')
print(dataset)
# Out:
# ******************Lista de datos*********************
# [['9', '4', '10'], ['4', '2', '7']]
# ******************Data Frame*********************
#    0  1   2
# 0  9  4  10
# 1  4  2   7
